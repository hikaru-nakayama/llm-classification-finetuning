# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/hikaru-nakayama/llm-classification-finetuning.git
# %cd /content/llm-classification-finetuning
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ["PATH"] = f"/root/.local/bin:{os.environ['PATH']}"
# !uv sync --dev

# %%
import os
os.environ["HF_HOME"] = "/content/hf_cache"
os.environ["TRANSFORMERS_CACHE"] = "/content/hf_cache"

# %%
python scripts/download_kaggle.py

# %%
from pathlib import Path
import shutil

src_dir = Path("/content/drive/MyDrive/llm-classification-finetuning/data/raw")
dst_dir = Path("/content/llm-classification-finetuning/data/raw")
dst_dir.mkdir(parents=True, exist_ok=True)

for name in ["train.csv", "test.csv"]:
    shutil.copy2(src_dir / name, dst_dir / name)

print("copy done")

# %%
# データ前処理
# !python scripts/run_preprocess.py

# %%
# 学習
# !python scripts/run_train.py

# %%
# 評価
# !python scripts/run_eval.py
